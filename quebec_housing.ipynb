# %%
import pandas as pd
import numpy as ny

# %%
df=pd.read_csv('quebec_housing_sales_v2.csv')

# %%
df.shape
# Out:
# (5000, 14)

# %%
df
# Out:
#       property_id            city         neighborhood  property_type  \
# 0               1     Châteauguay         Centre-Ville      Townhouse
# 1               2  Trois-Rivières  Cap-de-la-Madeleine         Duplex
# 2               3           Lévis               Charny      Townhouse
# 3               4           Laval           Fabreville  Single Family
# 4               5       Longueuil      Greenfield Park          Condo
# ...           ...             ...                  ...            ...
# 4995         4996      Sherbrooke          Lennoxville  Single Family
# 4996         4997        Rimouski      Rimouski Centre  Single Family
# 4997         4998        Montréal             Villeray         Duplex
# 4998         4999        Brossard            Secteur B       Bungalow
# 4999         5000      Terrebonne            Lachenaie          Condo
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# ...

# %%
# Easy
# Display the first 10 rows.
# Display the last 5 rows.
# Find the shape of the dataset.
# Display all column names.
# Find the data type of each column.
# Count the number of missing values in each column.
# Count the total number of properties.
# Print only the city, property_type, and sale_price columns.
# Find the average sale price.
# Find the highest sale price.

# %%
# Display the first 10 rows.
df.head(10)
# Out:
#    property_id            city         neighborhood  property_type  bedrooms  \
# 0            1     Châteauguay         Centre-Ville      Townhouse         3
# 1            2  Trois-Rivières  Cap-de-la-Madeleine         Duplex         4
# 2            3           Lévis               Charny      Townhouse         3
# 3            4           Laval           Fabreville  Single Family         3
# 4            5       Longueuil      Greenfield Park          Condo         2
# 5            6   Victoriaville         Centre-Ville  Single Family         4
# 6            7        Montréal            Outremont      Townhouse         3
# 7            8      Sherbrooke          Lennoxville  Single Family         4
# 8            9           Lévis        Saint-Nicolas      Townhouse         4
# 9           10    Saint-Jérôme         Bellefeuille       Bungalow         4
#
#    bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
# Display the last 5 rows.
df.tail()
# Out:
#       property_id        city     neighborhood  property_type  bedrooms  \
# 4995         4996  Sherbrooke      Lennoxville  Single Family         4
# 4996         4997    Rimouski  Rimouski Centre  Single Family         5
# 4997         4998    Montréal         Villeray         Duplex         4
# 4998         4999    Brossard        Secteur B       Bungalow         2
# 4999         5000  Terrebonne        Lachenaie          Condo         1
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# 4995          4              1411         9036.0        1985              NaN
# 4996          2              1432         6474.0        2010              NaN
# 4997          2              1692         6070.0        1953              NaN
# 4998          1               954         4686.0        1994           2013.0
# 4999          1               861            NaN        1969           2010.0
#
#      garage basement  sale_year  sale_price
# ...

# %%
# Find the shape of the dataset.
df.shape
# Out:
# (5000, 14)

# %%
# Display all column names.
df.columns
# Out:
# Index(['property_id', 'city', 'neighborhood', 'property_type', 'bedrooms',
#        'bathrooms', 'living_area_sqft', 'lot_size_sqft', 'year_built',
#        'renovation_year', 'garage', 'basement', 'sale_year', 'sale_price'],
#       dtype='object')

# %%
# Find the data type of each column.
df.dtypes
# Out:
# property_id           int64
# city                 object
# neighborhood         object
# property_type        object
# bedrooms              int64
# bathrooms             int64
# living_area_sqft      int64
# lot_size_sqft       float64
# year_built            int64
# renovation_year     float64
# garage               object
# basement             object
# sale_year             int64
# sale_price            int64
# dtype: object

# %%
# Count the number of missing values in each column.
df.isna().sum()
# Out:
# property_id            0
# city                   0
# neighborhood           0
# property_type          0
# bedrooms               0
# bathrooms              0
# living_area_sqft       0
# lot_size_sqft       1211
# year_built             0
# renovation_year     3408
# garage                 0
# basement               0
# sale_year              0
# sale_price             0
# dtype: int64

# %%
# Count the total number of properties.
df['property_id'].count()
# Out:
# np.int64(5000)

# %%
# Print only the city, property_type, and sale_price columns.
df[['property_type','city','property_type','sale_price']]
# Out:
#       property_type            city  property_type  sale_price
# 0         Townhouse     Châteauguay      Townhouse      326000
# 1            Duplex  Trois-Rivières         Duplex      444000
# 2         Townhouse           Lévis      Townhouse      273000
# 3     Single Family           Laval  Single Family      465000
# 4             Condo       Longueuil          Condo      371000
# ...             ...             ...            ...         ...
# 4995  Single Family      Sherbrooke  Single Family      406000
# 4996  Single Family        Rimouski  Single Family      198000
# 4997         Duplex        Montréal         Duplex      680000
# 4998       Bungalow        Brossard       Bungalow      431000
# 4999          Condo      Terrebonne          Condo      472000
#
# [5000 rows x 4 columns]

# %%
# Find the average sale price.
df['sale_price'].mean()
# Out:
# np.float64(480214.0)

# %%
# Find the highest sale price.
df.loc[df['sale_price'].idxmax(),'city']
# Out:
# 'Longueuil'

# %%
# Medium
# Find the property with the highest sale price.
# Find the property with the lowest sale price.
# Find all houses with more than 3 bedrooms.
# Find all properties with at least 2 bathrooms.
# Find all properties sold after 2020.
# Find the average living area.
# Find the average lot size.
# Count how many properties are in each city.
# Count how many properties belong to each property type.
# Find the average sale price for each city.

# %%
# Find the property with the highest sale price.
df.loc[df['sale_price'].idxmax()]
# Out:
# property_id                    3651
# city                      Longueuil
# neighborhood        Greenfield Park
# property_type               Triplex
# bedrooms                          6
# bathrooms                         4
# living_area_sqft               2327
# lot_size_sqft                4428.0
# year_built                     2011
# renovation_year                 NaN
# garage                          Yes
# basement                        Yes
# sale_year                      2025
# sale_price                  1425000
# Name: 3650, dtype: object

# %%
# Find the property with the lowest sale price.
df.loc[df['sale_price'].idxmin()]
# Out:
# property_id                       2902
# city                       Baie-Comeau
# neighborhood        Baie-Comeau Centre
# property_type                    Condo
# bedrooms                             2
# bathrooms                            1
# living_area_sqft                   638
# lot_size_sqft                      NaN
# year_built                        1962
# renovation_year                    NaN
# garage                             Yes
# basement                            No
# sale_year                         2022
# sale_price                      114000
# Name: 2901, dtype: object

# %%
# Find all houses with more than 3 bedrooms.
df[df['bedrooms']<=3]
# Out:
#       property_id                        city     neighborhood  property_type  \
# 0               1                 Châteauguay     Centre-Ville      Townhouse
# 2               3                       Lévis           Charny      Townhouse
# 3               4                       Laval       Fabreville  Single Family
# 4               5                   Longueuil  Greenfield Park          Condo
# 6               7                    Montréal        Outremont      Townhouse
# ...           ...                         ...              ...            ...
# 4988         4989  Saint-Bruno-de-Montarville     Centre-Ville  Single Family
# 4989         4990                      Québec           Vanier          Condo
# 4992         4993                    Montréal         Ahuntsic      Townhouse
# 4998         4999                    Brossard        Secteur B       Bungalow
# 4999         5000                  Terrebonne        Lachenaie          Condo
#
# ...

# %%
# Find all properties with at least 2 bathrooms.
df[df['bathrooms']>=2]
# Out:
#       property_id            city         neighborhood  property_type  \
# 0               1     Châteauguay         Centre-Ville      Townhouse
# 1               2  Trois-Rivières  Cap-de-la-Madeleine         Duplex
# 3               4           Laval           Fabreville  Single Family
# 4               5       Longueuil      Greenfield Park          Condo
# 5               6   Victoriaville         Centre-Ville  Single Family
# ...           ...             ...                  ...            ...
# 4993         4994     Châteauguay         Centre-Ville         Duplex
# 4994         4995      Repentigny           Le Gardeur  Single Family
# 4995         4996      Sherbrooke          Lennoxville  Single Family
# 4996         4997        Rimouski      Rimouski Centre  Single Family
# 4997         4998        Montréal             Villeray         Duplex
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# ...

# %%
# Find all properties sold after 2020.
df[df['sale_year']>2020]
# Out:
#       property_id            city         neighborhood  property_type  \
# 0               1     Châteauguay         Centre-Ville      Townhouse
# 1               2  Trois-Rivières  Cap-de-la-Madeleine         Duplex
# 2               3           Lévis               Charny      Townhouse
# 3               4           Laval           Fabreville  Single Family
# 4               5       Longueuil      Greenfield Park          Condo
# ...           ...             ...                  ...            ...
# 4995         4996      Sherbrooke          Lennoxville  Single Family
# 4996         4997        Rimouski      Rimouski Centre  Single Family
# 4997         4998        Montréal             Villeray         Duplex
# 4998         4999        Brossard            Secteur B       Bungalow
# 4999         5000      Terrebonne            Lachenaie          Condo
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# ...

# %%
# Find the average living area.
df['living_area_sqft'].mean()
# Out:
# np.float64(1313.6938)

# %%
# Find the average lot size.
df['lot_size_sqft'].mean()
# Out:
# np.float64(6257.154658221167)

# %%
# Count how many properties are in each city.
df.groupby('city')['property_id'].count()
# Out:
# city
# Alma                           36
# Baie-Comeau                    22
# Blainville                    112
# Boucherville                   72
# Brossard                      244
# Candiac                        55
# Châteauguay                    81
# Dollard-des-Ormeaux            82
# Drummondville                  89
# Gatineau                      207
# Granby                         90
# Laval                         460
# Longueuil                     394
# Lévis                         124
# Mirabel                        90
# Montréal                      919
# Pointe-Claire                  51
# Québec                        529
# Repentigny                    147
# Rimouski                       49
# Rouyn-Noranda                  27
# Saguenay                       93
# Saint-Bruno-de-Montarville     57
# Saint-Jean-sur-Richelieu      121
# Saint-Jérôme                  117
# Sept-Îles                      36
# Sherbrooke                    220
# ...

# %%
# Count how many properties belong to each property type.
df.groupby('property_type')['property_type'].count()
# Out:
# property_type
# Bungalow          139
# Condo            1211
# Duplex            493
# Single Family    2254
# Townhouse         649
# Triplex           254
# Name: property_type, dtype: int64

# %%
# Find the average sale price for each city.
df.groupby('city')['sale_price'].mean()
# Out:
# city
# Alma                          264861.111111
# Baie-Comeau                   171136.363636
# Blainville                    434892.857143
# Boucherville                  562833.333333
# Brossard                      542938.524590
# Candiac                       515090.909091
# Châteauguay                   368012.345679
# Dollard-des-Ormeaux           580707.317073
# Drummondville                 332876.404494
# Gatineau                      515371.980676
# Granby                        470544.444444
# Laval                         576630.434783
# Longueuil                     606675.126904
# Lévis                         361169.354839
# Mirabel                       434000.000000
# Montréal                      529662.676823
# Pointe-Claire                 599725.490196
# Québec                        385296.786389
# Repentigny                    575517.006803
# Rimouski                      249081.632653
# Rouyn-Noranda                 416037.037037
# ...

# %%
# Find the average sale price for each property type.
# Find the average number of bedrooms in each city.
# Find the average living area for each property type.
# Find the city with the highest average sale price.
# Find the property type with the highest average sale price.
# Find the total number of properties sold in each year.
# Find the average sale price by sale year.
# Find the average lot size by city.
# Find the average bathrooms by property type.
# Find the maximum sale price in each city.

# %%
# Find the average sale price for each property type.
df.groupby("property_type")["sale_price"].mean()
# Out:
# property_type
# Bungalow         471460.431655
# Condo            366817.506193
# Duplex           547251.521298
# Single Family    524967.613132
# Townhouse        359906.009245
# Triplex          805787.401575
# Name: sale_price, dtype: float64

# %%
# Find the average number of bedrooms in each city.
df.groupby("city")["bedrooms"].mean()
# Out:
# city
# Alma                          3.694444
# Baie-Comeau                   3.090909
# Blainville                    3.357143
# Boucherville                  3.597222
# Brossard                      3.393443
# Candiac                       3.581818
# Châteauguay                   3.345679
# Dollard-des-Ormeaux           3.670732
# Drummondville                 3.382022
# Gatineau                      3.574879
# Granby                        3.500000
# Laval                         3.504348
# Longueuil                     3.522843
# Lévis                         3.443548
# Mirabel                       3.500000
# Montréal                      3.461371
# Pointe-Claire                 3.647059
# Québec                        3.529301
# Repentigny                    3.319728
# Rimouski                      3.612245
# Rouyn-Noranda                 3.703704
# Saguenay                      3.731183
# Saint-Bruno-de-Montarville    3.649123
# Saint-Jean-sur-Richelieu      3.396694
# ...

# %%
# Find the average living area for each property type.
df.groupby("property_type")["living_area_sqft"].mean()
# Out:
# property_type
# Bungalow         1025.251799
# Condo             751.389761
# Duplex           1718.318458
# Single Family    1499.908607
# Townhouse        1078.032357
# Triplex          2316.763780
# Name: living_area_sqft, dtype: float64

# %%
df.columns
# Out:
# Index(['property_id', 'city', 'neighborhood', 'property_type', 'bedrooms',
#        'bathrooms', 'living_area_sqft', 'lot_size_sqft', 'year_built',
#        'renovation_year', 'garage', 'basement', 'sale_year', 'sale_price'],
#       dtype='object')

# %%
# Find the city with the highest average sale price.
df.groupby(["city"])['sale_price'].mean().sort_values(ascending=0).head(1)
# Out:
# city
# Terrebonne    612666.666667
# Name: sale_price, dtype: float64

# %%
# Find the property type with the highest average sale price.
df.groupby(["property_type"])['sale_price'].mean().sort_values(ascending=0).head(1)
# Out:
# property_type
# Triplex    805787.401575
# Name: sale_price, dtype: float64

# %%
# Find the total number of properties sold in each year.
df.groupby(["sale_year"])['property_id'].count()
# Out:
# sale_year
# 2021     557
# 2022     816
# 2023     982
# 2024    1302
# 2025    1343
# Name: property_id, dtype: int64

# %%
# Find the average sale price by sale year.
df.groupby(["sale_year"])['sale_price'].mean()
# Out:
# sale_year
# 2021    396542.190305
# 2022    425774.509804
# 2023    457675.152749
# 2024    501804.915515
# 2025    543542.069993
# Name: sale_price, dtype: float64

# %%
# Find the average lot size by city.
df.groupby(["city"])['lot_size_sqft'].mean()
# Out:
# city
# Alma                          5444.133333
# Baie-Comeau                   5579.285714
# Blainville                    6129.632911
# Boucherville                  5666.824561
# Brossard                      6031.093923
# Candiac                       6039.558140
# Châteauguay                   6391.898305
# Dollard-des-Ormeaux           6865.092308
# Drummondville                 6215.686567
# Gatineau                      6038.515924
# Granby                        6352.078125
# Laval                         6232.836795
# Longueuil                     6383.219048
# Lévis                         6202.705882
# Mirabel                       6126.984848
# Montréal                      6270.173601
# Pointe-Claire                 5856.000000
# Québec                        6276.160891
# Repentigny                    6755.064815
# Rimouski                      7428.135135
# Rouyn-Noranda                 6220.200000
# Saguenay                      6483.791667
# ...

# %%
# Find the average bathrooms by property type.
df.groupby(["property_type"])['bathrooms'].mean()
# Out:
# property_type
# Bungalow         1.496403
# Condo            1.499587
# Duplex           2.995943
# Single Family    2.532831
# Townhouse        1.979969
# Triplex          4.464567
# Name: bathrooms, dtype: float64

# %%
# Find the maximum sale price in each city.
df.groupby(["city"])['sale_price'].max()
# Out:
# city
# Alma                           372000
# Baie-Comeau                    280000
# Blainville                     761000
# Boucherville                  1170000
# Brossard                      1088000
# Candiac                        861000
# Châteauguay                    704000
# Dollard-des-Ormeaux            973000
# Drummondville                  609000
# Gatineau                       996000
# Granby                        1063000
# Laval                         1214000
# Longueuil                     1425000
# Lévis                          691000
# Mirabel                        880000
# Montréal                      1417000
# Pointe-Claire                 1207000
# Québec                         834000
# Repentigny                    1090000
# Rimouski                       406000
# Rouyn-Noranda                  671000
# Saguenay                       523000
# Saint-Bruno-de-Montarville     935000
# Saint-Jean-sur-Richelieu       658000
# ...

# %%
# Filtering Practice
# Find properties with:
# More than 4 bedrooms
# At least 3 bathrooms
# Find properties where:
# Garage = Yes
# Basement = Yes
# Find properties with sale price greater than $800,000.
# Find properties built before 1990.
# Find renovated properties (renovation_year is not missing).
# Find properties whose living area is greater than 2500 sqft.
# Find properties with lot size greater than 6000 sqft.
# Find all condos in Montreal (or any city present in your dataset).
# Find properties sold in 2023.
# Find properties costing between $500,000 and $700,000.

# %%
df.columns
# Out:
# Index(['property_id', 'city', 'neighborhood', 'property_type', 'bedrooms',
#        'bathrooms', 'living_area_sqft', 'lot_size_sqft', 'year_built',
#        'renovation_year', 'garage', 'basement', 'sale_year', 'sale_price'],
#       dtype='object')

# %%
# Find properties with:
# More than 4 bedrooms
# At least 3 bathrooms
df[(df['bedrooms']>4)&(df["bathrooms"]>=3)]
# Out:
#       property_id         city        neighborhood  property_type  bedrooms  \
# 20             21        Laval            Duvernay         Duplex         5
# 22             23  Châteauguay        Centre-Ville        Triplex         6
# 24             25     Montréal              Verdun         Duplex         6
# 27             28     Gatineau                Hull         Duplex         6
# 29             30      Mirabel         Saint-Canut  Single Family         6
# ...           ...          ...                 ...            ...       ...
# 4971         4972    Sept-Îles    Sept-Îles Centre        Triplex         7
# 4973         4974  Baie-Comeau  Baie-Comeau Centre  Single Family         5
# 4974         4975     Montréal            Villeray  Single Family         5
# 4991         4992     Montréal         Ville-Marie        Triplex         6
# 4994         4995   Repentigny          Le Gardeur  Single Family         6
#
# ...

# %%
# Find properties where:
# Garage = Yes
# Basement = Yes
df[(df['garage']=='Yes')&(df['basement']=='Yes')][['property_id','city']]
# Out:
#       property_id                        city
# 2               3                       Lévis
# 3               4                       Laval
# 5               6               Victoriaville
# 7               8                  Sherbrooke
# 9              10                Saint-Jérôme
# ...           ...                         ...
# 4988         4989  Saint-Bruno-de-Montarville
# 4990         4991                    Montréal
# 4991         4992                    Montréal
# 4994         4995                  Repentigny
# 4998         4999                    Brossard
#
# [2239 rows x 2 columns]

# %%
# Find properties with sale price greater than $800,000.
df[df["sale_price"]>800000]
# Out:
#       property_id        city     neighborhood  property_type  bedrooms  \
# 39             40    Montréal          Lachine         Duplex         5
# 54             55   Longueuil  Vieux-Longueuil  Single Family         6
# 65             66       Laval       Fabreville        Triplex         6
# 113           114    Gatineau  Gatineau Centre  Single Family         3
# 158           159       Laval         Duvernay  Single Family         6
# ...           ...         ...              ...            ...       ...
# 4854         4855       Laval         Chomedey        Triplex         7
# 4888         4889       Laval           Vimont        Triplex         8
# 4974         4975    Montréal         Villeray  Single Family         5
# 4981         4982  Terrebonne        Lachenaie  Single Family         3
# 4991         4992    Montréal      Ville-Marie        Triplex         6
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
# Find properties built before 1990.
df[df["year_built"]<1990]
# Out:
#       property_id           city   neighborhood  property_type  bedrooms  \
# 2               3          Lévis         Charny      Townhouse         3
# 3               4          Laval     Fabreville  Single Family         3
# 5               6  Victoriaville   Centre-Ville  Single Family         4
# 6               7       Montréal      Outremont      Townhouse         3
# 8               9          Lévis  Saint-Nicolas      Townhouse         4
# ...           ...            ...            ...            ...       ...
# 4987         4988    Châteauguay   Centre-Ville  Single Family         3
# 4992         4993       Montréal       Ahuntsic      Townhouse         3
# 4995         4996     Sherbrooke    Lennoxville  Single Family         4
# 4997         4998       Montréal       Villeray         Duplex         4
# 4999         5000     Terrebonne      Lachenaie          Condo         1
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
# Find renovated properties (renovation_year is not missing).
df[df['renovation_year'].notnull()]
# Out:
#       property_id                      city         neighborhood  \
# 1               2            Trois-Rivières  Cap-de-la-Madeleine
# 3               4                     Laval           Fabreville
# 4               5                 Longueuil      Greenfield Park
# 8               9                     Lévis        Saint-Nicolas
# 19             20                  Val-d'Or      Val-d'Or Centre
# ...           ...                       ...                  ...
# 4983         4984  Saint-Jean-sur-Richelieu         Centre-Ville
# 4992         4993                  Montréal             Ahuntsic
# 4993         4994               Châteauguay         Centre-Ville
# 4998         4999                  Brossard            Secteur B
# 4999         5000                Terrebonne            Lachenaie
#
#       property_type  bedrooms  bathrooms  living_area_sqft  lot_size_sqft  \
# 1            Duplex         4          4              1807         5869.0
# ...

# %%
# Find properties whose living area is greater than 2500 sqft.
df[df['living_area_sqft']>2500]
# Out:
#       property_id          city         neighborhood property_type  bedrooms  \
# 65             66         Laval           Fabreville       Triplex         6
# 103           104  Boucherville  Boucherville Centre       Triplex         6
# 188           189         Laval             Chomedey       Triplex         6
# 221           222         Laval             Chomedey       Triplex         7
# 225           226      Montréal              Lachine       Triplex         5
# ...           ...           ...                  ...           ...       ...
# 4215         4216     Longueuil         Saint-Hubert       Triplex         5
# 4695         4696     Longueuil      Vieux-Longueuil       Triplex         6
# 4746         4747    Sherbrooke          Rock Forest       Triplex         6
# 4864         4865        Québec             Beauport       Triplex         6
# 4991         4992      Montréal          Ville-Marie       Triplex         6
#
# ...

# %%
# Find properties with lot size greater than 6000 sqft.
df[df["lot_size_sqft"]>6000]
# Out:
#       property_id         city     neighborhood  property_type  bedrooms  \
# 3               4        Laval       Fabreville  Single Family         3
# 14             15      Mirabel   Sainte-Monique  Single Family         4
# 18             19  Châteauguay     Centre-Ville  Single Family         4
# 19             20     Val-d'Or  Val-d'Or Centre  Single Family         4
# 27             28     Gatineau             Hull         Duplex         6
# ...           ...          ...              ...            ...       ...
# 4990         4991     Montréal    Saint-Léonard  Single Family         4
# 4994         4995   Repentigny       Le Gardeur  Single Family         6
# 4995         4996   Sherbrooke      Lennoxville  Single Family         4
# 4996         4997     Rimouski  Rimouski Centre  Single Family         5
# 4997         4998     Montréal         Villeray         Duplex         4
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
# Find all condos in Montreal (or any city present in your dataset).
df[(df['property_type'] == 'Condo') & (df['city'] == 'Montreal')]
# Out:
# Empty DataFrame
# Columns: [property_id, city, neighborhood, property_type, bedrooms, bathrooms, living_area_sqft, lot_size_sqft, year_built, renovation_year, garage, basement, sale_year, sale_price]
# Index: []

# %%
# Find all condos in Montreal (or any city present in your dataset).
df[df['property_type'] == 'Condo']
# Out:
#       property_id         city        neighborhood property_type  bedrooms  \
# 4               5    Longueuil     Greenfield Park         Condo         2
# 10             11    Longueuil  Le Vieux-Longueuil         Condo         1
# 13             14   Repentigny          Le Gardeur         Condo         1
# 15             16      Candiac      Candiac Centre         Condo         2
# 16             17  Baie-Comeau  Baie-Comeau Centre         Condo         3
# ...           ...          ...                 ...           ...       ...
# 4977         4978     Rimouski     Rimouski Centre         Condo         3
# 4984         4985        Laval          Fabreville         Condo         2
# 4986         4987       Québec          Sainte-Foy         Condo         1
# 4989         4990       Québec              Vanier         Condo         2
# 4999         5000   Terrebonne           Lachenaie         Condo         1
#
# ...

# %%
# Find properties costing between $500,000 and $700,000.
df[(df['sale_price']>500000)&(df['sale_price']<700000)]
# Out:
#       property_id                        city        neighborhood  \
# 10             11                   Longueuil  Le Vieux-Longueuil
# 13             14                  Repentigny          Le Gardeur
# 20             21                       Laval            Duvernay
# 22             23                 Châteauguay        Centre-Ville
# 23             24                    Montréal           Outremont
# ...           ...                         ...                 ...
# 4978         4979                    Montréal            Ahuntsic
# 4988         4989  Saint-Bruno-de-Montarville        Centre-Ville
# 4990         4991                    Montréal       Saint-Léonard
# 4994         4995                  Repentigny          Le Gardeur
# 4997         4998                    Montréal            Villeray
#
#       property_type  bedrooms  bathrooms  living_area_sqft  lot_size_sqft  \
# 10            Condo         1          2               768            NaN
# ...

# %%
# Find properties sold in 2023.
df[df['sale_year']==2023]
# Out:
#       property_id           city   neighborhood  property_type  bedrooms  \
# 3               4          Laval     Fabreville  Single Family         3
# 5               6  Victoriaville   Centre-Ville  Single Family         4
# 6               7       Montréal      Outremont      Townhouse         3
# 7               8     Sherbrooke    Lennoxville  Single Family         4
# 17             18          Lévis   Lévis Centre          Condo         2
# ...           ...            ...            ...            ...       ...
# 4986         4987         Québec     Sainte-Foy          Condo         1
# 4990         4991       Montréal  Saint-Léonard  Single Family         4
# 4992         4993       Montréal       Ahuntsic      Townhouse         3
# 4994         4995     Repentigny     Le Gardeur  Single Family         6
# 4995         4996     Sherbrooke    Lennoxville  Single Family         4
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
df['property_type'].unique()
# Out:
# array(['Townhouse', 'Duplex', 'Single Family', 'Condo', 'Bungalow',
#        'Triplex'], dtype=object)

# %%
# Sorting Practice
# Find the top 10 most expensive properties.
# Find the cheapest 10 properties.
# Sort properties by living area.
# Sort by sale price and then by bedrooms.
# Find the oldest property.

# %%
# Find the top 10 most expensive properties.
df.sort_values(by="sale_price",ascending=0).head(10)
# Out:
#       property_id        city           neighborhood property_type  bedrooms  \
# 3650         3651   Longueuil        Greenfield Park       Triplex         6
# 2942         2943    Montréal  Hochelaga-Maisonneuve       Triplex         6
# 1446         1447    Montréal     Plateau-Mont-Royal       Triplex         7
# 354           355    Montréal          Saint-Léonard       Triplex         4
# 1372         1373    Montréal    Pointe-aux-Trembles       Triplex         5
# 1182         1183  Terrebonne              Lachenaie       Triplex         6
# 4440         4441    Montréal               Villeray       Triplex         6
# 1008         1009    Montréal     Plateau-Mont-Royal       Triplex         5
# 2496         2497  Terrebonne              Lachenaie       Triplex         8
# 4160         4161    Montréal    Pointe-aux-Trembles       Triplex         6
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# ...

# %%
# Find the cheapest 10 properties.
df.sort_values(by="sale_price",ascending=1).head(1)
# Out:
#       property_id         city        neighborhood property_type  bedrooms  \
# 2901         2902  Baie-Comeau  Baie-Comeau Centre         Condo         2
#
#       bathrooms  living_area_sqft  lot_size_sqft  year_built  renovation_year  \
# 2901          1               638            NaN        1962              NaN
#
#      garage basement  sale_year  sale_price
# 2901    Yes       No       2022      114000

# %%
# Sort properties by living area.
df.sort_values(by="living_area_sqft",ascending=0)
# Out:
#       property_id                 city         neighborhood property_type  \
# 335           336                Laval             Duvernay       Triplex
# 1057         1058             Montréal  Pointe-aux-Trembles       Triplex
# 2174         2175             Brossard            Secteur B       Triplex
# 2895         2896       Trois-Rivières         Centre-Ville       Triplex
# 258           259  Dollard-des-Ormeaux          West Island       Triplex
# ...           ...                  ...                  ...           ...
# 419           420                Laval             Chomedey         Condo
# 303           304               Québec          Lebourgneuf         Condo
# 295           296          Baie-Comeau   Baie-Comeau Centre         Condo
# 3179         3180           Terrebonne            La Plaine         Condo
# 3062         3063           Terrebonne            La Plaine         Condo
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# ...

# %%
# Sort by sale price and then by bedrooms.
df.sort_values(by=['sale_price','bedrooms'],ascending=True)
# Out:
#       property_id         city           neighborhood property_type  bedrooms  \
# 2901         2902  Baie-Comeau     Baie-Comeau Centre         Condo         2
# 1478         1479    Sept-Îles       Sept-Îles Centre         Condo         2
# 1223         1224  Baie-Comeau     Baie-Comeau Centre         Condo         2
# 1858         1859    Sept-Îles       Sept-Îles Centre         Condo         1
# 2033         2034  Baie-Comeau     Baie-Comeau Centre         Condo         3
# ...           ...          ...                    ...           ...       ...
# 1372         1373     Montréal    Pointe-aux-Trembles       Triplex         5
# 354           355     Montréal          Saint-Léonard       Triplex         4
# 1446         1447     Montréal     Plateau-Mont-Royal       Triplex         7
# 2942         2943     Montréal  Hochelaga-Maisonneuve       Triplex         6
# 3650         3651    Longueuil        Greenfield Park       Triplex         6
#
# ...

# %%
# Find the oldest property.
df.loc[df['year_built'].idxmin()]
# Out:
# property_id                   750
# city                     Montréal
# neighborhood        Saint-Léonard
# property_type           Townhouse
# bedrooms                        3
# bathrooms                       2
# living_area_sqft              944
# lot_size_sqft              3554.0
# year_built                   1900
# renovation_year               NaN
# garage                        Yes
# basement                      Yes
# sale_year                    2023
# sale_price                 333000
# Name: 749, dtype: object

# %%
# Advanced
# Create a new column:
# price_per_sqft = sale_price / living_area_sqft
# Find the property with the highest price per square foot.
# Find the average price per square foot by city.
# Which city has the highest average price per square foot?
# Find the most expensive property in each city.
# Find the newest property in each city.
# Find the average sale price for properties with garages versus those without.
# Compare the average sale price of renovated vs. non-renovated properties.
# Find the city with the largest average living area.
# Find the property type with the highest average number of bedrooms.

# %%
# Advanced
# Create a new column:
# price_per_sqft = sale_price / living_area_sqft
df['price_per_sqft']=df['sale_price']/df['living_area_sqft']

# %%
df['price_per_sqft']
# Out:
# 0       281.034483
# 1       245.711123
# 2       339.975093
# 3       429.362881
# 4       519.607843
#            ...
# 4995    287.739192
# 4996    138.268156
# 4997    401.891253
# 4998    451.781971
# 4999    548.199768
# Name: price_per_sqft, Length: 5000, dtype: float64

# %%
# Find the property with the highest price per square foot.
df.loc[df['price_per_sqft'].idxmax()]
# Out:
# property_id                        894
# city                         Longueuil
# neighborhood        Le Vieux-Longueuil
# property_type                    Condo
# bedrooms                             2
# bathrooms                            2
# living_area_sqft                   620
# lot_size_sqft                      NaN
# year_built                        1978
# renovation_year                 2021.0
# garage                             Yes
# basement                            No
# sale_year                         2025
# sale_price                      579000
# price_per_sqft              933.870968
# Name: 893, dtype: object

# %%
# Find the average price per square foot by city.
df.groupby(by='city')['price_per_sqft'].mean()
# Out:
# city
# Alma                          190.984762
# Baie-Comeau                   165.428076
# Blainville                    369.104870
# Boucherville                  447.947406
# Brossard                      459.753013
# Candiac                       405.632372
# Châteauguay                   293.869167
# Dollard-des-Ormeaux           447.132274
# Drummondville                 279.538037
# Gatineau                      420.474135
# Granby                        394.375487
# Laval                         461.523060
# Longueuil                     482.773025
# Lévis                         306.036915
# Mirabel                       357.793158
# Montréal                      421.419579
# Pointe-Claire                 463.386221
# Québec                        306.774791
# Repentigny                    485.508047
# Rimouski                      203.327342
# Rouyn-Noranda                 327.650981
# Saguenay                      235.717559
# Saint-Bruno-de-Montarville    456.642447
# ...

# %%
# Which city has the highest average price per square foot?
df.groupby(by='city')['price_per_sqft'].mean().sort_values(ascending=0).head(1)
# Out:
# city
# Terrebonne    488.373402
# Name: price_per_sqft, dtype: float64

# %%
# Find the most expensive property in each city.
df.loc[df.groupby(by="city")['sale_price'].idxmax()]
# Out:
#       property_id                        city           neighborhood  \
# 2169         2170                        Alma            Alma Centre
# 4973         4974                 Baie-Comeau     Baie-Comeau Centre
# 2993         2994                  Blainville      Blainville Centre
# 2460         2461                Boucherville    Boucherville Centre
# 2174         2175                    Brossard              Secteur B
# 3228         3229                     Candiac         Candiac Centre
# 3609         3610                 Châteauguay           Centre-Ville
# 191           192         Dollard-des-Ormeaux            West Island
# 3053         3054               Drummondville          Saint-Charles
# 2723         2724                    Gatineau                   Hull
# 1296         1297                      Granby           Centre-Ville
# 3114         3115                       Laval               Duvernay
# 3650         3651                   Longueuil        Greenfield Park
# ...

# %%
# Find the newest property in each city.
df.loc[df['year_built'].idxmax()]
# Out:
# property_id                     26
# city                       Mirabel
# neighborhood        Sainte-Monique
# property_type               Duplex
# bedrooms                         5
# bathrooms                        2
# living_area_sqft              1612
# lot_size_sqft               4032.0
# year_built                    2023
# renovation_year                NaN
# garage                         Yes
# basement                        No
# sale_year                     2025
# sale_price                  589000
# price_per_sqft          365.384615
# Name: 25, dtype: object

# %%
# Find the average sale price for properties with garages versus those without.
df.groupby('garage')['sale_price'].mean()
# Out:
# garage
# No     456253.280840
# Yes    490719.217491
# Name: sale_price, dtype: float64

# %%
# Compare the average sale price of renovated vs. non-renovated properties.
avg_renovated = df[df['renovation_year'].notna()]['sale_price'].mean()
avg_not_renovated = df[df['renovation_year'].isna()]['sale_price'].mean()

print("Renovated:", avg_renovated)
print("Not Renovated:", avg_not_renovated)
# Out:
# Renovated: 495913.9447236181
# Not Renovated: 472879.9882629108

# %%
# Find the city with the largest average living area.
df.groupby(by='city')['living_area_sqft'].mean().sort_values(ascending=0).head(1)
# Out:
# city
# Alma    1458.611111
# Name: living_area_sqft, dtype: float64

# %%
# Find the property type with the highest average number of bedrooms.
df.groupby(by='property_type')['bedrooms'].mean().sort_values(ascending=0).head(1)
# Out:
# property_type
# Triplex    6.047244
# Name: bedrooms, dtype: float64

# %%
# Challenge Questions
# Find the top 5 cities with the highest average property prices.
# Find the top 10 largest houses by living area.
# Find properties that have:
# Garage = Yes
# Basement = Yes
# More than 4 bedrooms
# Sale price under the dataset's average sale price.
# Rank cities by average sale price.
# Find the most expensive property type in each city.

# %%
# Find the top 5 cities with the highestp average property prices.
df.groupby(by='city')['sale_price'].mean().sort_values(ascending=0).head(5)
# Out:
# city
# Terrebonne             612666.666667
# Longueuil              606675.126904
# Pointe-Claire          599725.490196
# Dollard-des-Ormeaux    580707.317073
# Laval                  576630.434783
# Name: sale_price, dtype: float64

# %%
# Find the top 10 largest houses by living area.
df.sort_values(by='living_area_sqft',ascending=0).head(10)
# Out:
#       property_id                 city         neighborhood property_type  \
# 335           336                Laval             Duvernay       Triplex
# 1057         1058             Montréal  Pointe-aux-Trembles       Triplex
# 2174         2175             Brossard            Secteur B       Triplex
# 2895         2896       Trois-Rivières         Centre-Ville       Triplex
# 258           259  Dollard-des-Ormeaux          West Island       Triplex
# 1182         1183           Terrebonne            Lachenaie       Triplex
# 3644         3645          Châteauguay         Centre-Ville       Triplex
# 704           705              Candiac       Candiac Centre       Triplex
# 3085         3086        Rouyn-Noranda         Rouyn Centre       Triplex
# 1100         1101        Victoriaville         Centre-Ville       Triplex
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# 335          5          4              2967         6456.0        2002
# ...

# %%
# Find properties that have:
# Garage = Yes
# Basement = Yes
# More than 4 bedrooms
# Sale price under the dataset's average sale price.
avg_price=df['sale_price'].mean()
df[(df['garage']=='Yes')&(df['basement']=='Yes')&(df['bedrooms']>4)&(df['sale_price']<avg_price)]
# Out:
#       property_id            city          neighborhood  property_type  \
# 91             92  Trois-Rivières  Trois-Rivières-Ouest  Single Family
# 110           111          Québec            Val-Bélair  Single Family
# 130           131        Saguenay             Jonquière  Single Family
# 151           152      Sherbrooke           Lennoxville  Single Family
# 156           157       Longueuil          Saint-Hubert  Single Family
# ...           ...             ...                   ...            ...
# 4932         4933   Rouyn-Noranda          Rouyn Centre  Single Family
# 4946         4947        Saguenay             Jonquière  Single Family
# 4963         4964          Québec           Lebourgneuf  Single Family
# 4971         4972       Sept-Îles      Sept-Îles Centre        Triplex
# 4973         4974     Baie-Comeau    Baie-Comeau Centre  Single Family
#
#       bedrooms  bathrooms  living_area_sqft  lot_size_sqft  year_built  \
# ...

# %%
# Rank cities by average sale price.
df.groupby('city')['sale_price'].mean().sort_values(ascending=0)
# Out:
# city
# Terrebonne                    612666.666667
# Longueuil                     606675.126904
# Pointe-Claire                 599725.490196
# Dollard-des-Ormeaux           580707.317073
# Laval                         576630.434783
# Repentigny                    575517.006803
# Boucherville                  562833.333333
# Saint-Bruno-de-Montarville    560859.649123
# Brossard                      542938.524590
# Montréal                      529662.676823
# Gatineau                      515371.980676
# Candiac                       515090.909091
# Vaudreuil-Dorion              480607.594937
# Granby                        470544.444444
# Blainville                    434892.857143
# Mirabel                       434000.000000
# Victoriaville                 419017.857143
# Rouyn-Noranda                 416037.037037
# Sherbrooke                    405150.000000
# Québec                        385296.786389
# Saint-Jérôme                  372991.452991
# ...
